# %% [markdown]
# # Gamer AI for game BreakoutNoFrameskip-v4

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Checking GPU connection status

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
    print('Can\'t connect to GPU.')
else:
    print(gpu_info)
# Out:
# Sat Sep  9 03:43:40 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 526.98       Driver Version: 526.98       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   59C    P8     3W /  N/A |    178MiB /  4096MiB |      2%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Initializing environment and installing dependencies

# %%
# !pip install stable-baselines[mpi]
#Download and install ROMs
# !gdown -q http://www.atarimania.com/roms/Roms.rar
# !pip install -q unrar
# !mkdir ./roms_atari
# !unrar x Roms.rar ./roms_atari
# !pip install atari-py
# !python -m atari_py.import_roms ./roms_atari

# %%
import os
import gym
from gym.wrappers import FrameStack
from gym.wrappers.monitoring.video_recorder import VideoRecorder
from gym.wrappers.atari_preprocessing import AtariPreprocessing
from collections import deque
import numpy as np
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import Huber

# %%
# Initializing environment
env = gym.make('BreakoutNoFrameskip-v4', render_mode='rgb_array')
obs = env.reset()
print(obs[0].shape)
plt.imshow(env.render())
plt.axis('off')
plt.show()
# Out:
# (210, 160, 3)

# %% [markdown]
# ### Examining preprocessed environment

# %%
# Convert frames to Grayscale then rescale to (84,84)
env = AtariPreprocessing(env=env, screen_size=84, frame_skip=4, terminal_on_life_loss=True, scale_obs=True)
# Wrapping 4 frames into 1 line for model to learn the context of the environment at the same time
env = FrameStack(env=env, num_stack=4)
obs = np.array(env.reset()[0])

# Reshape shapre (C,H,W) to (H,W,C)
print(obs.transpose([1, 2, 0]).shape)
plt.title("Agent observation (4 frames)")
# Reshaping (C,H,W) to (H,C,W) then transfroming to (H, C*W)
plt.imshow(obs.transpose([1, 0, 2]).reshape([env.observation_space.shape[1], -1]))
plt.axis('off')
plt.show()
# Out:
# (84, 84, 4)

# %%
# Actions
print(env.action_space)
print(env.get_action_meanings())
# Out:
# Discrete(4)
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']

# %%
# Rewards
env.reset()
rewards = []
terminate = False
while not terminate:
    state, reward, terminate, truncated, info = env.step(env.action_space.sample())
    rewards.append(reward)
plt.plot(rewards)

# %% [markdown]
# ### Build DQN model

# %%
class DNNModel():
    def __init__(
            self,
            action_size: int = 4,
    ) -> None:
        self.output_shape = action_size


    def built_model(self, default_compiler:bool=False):
        input_layer = Input(shape=(84, 84, 4,))
        layer1 = Conv2D(32, (8,8), strides=(4,4), activation="relu")(input_layer)
        layer2 = Conv2D(64, (4,4), strides=(2,2), activation="relu")(layer1)
        layer3 = Conv2D(64, (3,3), strides=(1,1), activation="relu")(layer2)
        layer4 = Flatten()(layer3)
        layer5 = Dense(512, activation='relu')(layer4)
        output_layer = Dense(self.output_shape, activation='linear')(layer5)
        model = Model(inputs=input_layer, outputs=output_layer)

        if default_compiler:
            model.compile(optimizer=Adam(), loss=Huber())
        return model

class DQN():
    def __init__(
            self, 
            env: gym.Env, 
            discount_factor: float = 0.99,
            learning_rate: float = 25e-5,
            initial_epsilon: float = 1.0,
            epsilon_decay: float = 2e-5,
            epsilon_min: float = 0.01,
            epsilon_random_frames: int = 50000
    ) -> None:
        self.env = env
        self.state_space = env.observation_space.shape
        self.action_space = env.action_space.n
        self.discount_factor = discount_factor
        self.learning_rate = learning_rate
        self.epsilon = initial_epsilon
        self.epsilon_max = initial_epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.epsilon_random_frames = epsilon_random_frames
        self.main_model = DNNModel(self.action_space).built_model(default_compiler=True)
        self.target_model = DNNModel(self.action_space).built_model()
        self.max_memory_length = 100000
        self.memory = deque(maxlen=self.max_memory_length)

        self.main_model.summary()

        # self.target_model.set_weights(self.main_model.get_weights())

    def act(self, state, epsilon, time_steps):
        # Apply epsilon-greedy policy for picking the corresponding action
        if np.random.rand() < epsilon or time_steps < self.epsilon_random_frames:
            return np.random.randint(self.action_space)
        
        state_tensor = tf.convert_to_tensor(state)
        # Convert state_tensor with size (state_size,) to 1-batch state (num_batch, state_size) = (1, state_size)
        state_tensor = tf.expand_dims(state_tensor, axis=0)
        # Get Q values for correspoding actions predicted from model of the defined state
        q_value = self.main_model.predict(state_tensor)
        # Choose action with highest Q value from Q_values list with size (1, Q_values-actions_size)
        action = tf.argmax(q_value[0]).numpy()

        return action

    def update_epsilon(self, time_steps) -> None:
        self.epsilon = self.epsilon_min + (self.epsilon_max - self.epsilon_min)*np.exp(-self.epsilon_decay*time_steps)
        
    def store_experience(self, state, reward, action, next_state, terminate:bool):
        self.memory.append((state, reward, action, next_state, terminate))

    def clip_reward(self, reward):
        # Bin reward to {+1, 0, -1} by its sign.
        clipped_reward = max(min(reward, 1.0), -1.0)
        return clipped_reward

    def get_experience_sample(self, batch_size):
        # Get sample batch from experience storage 
        experiecne_batch = random.sample(self.memory, batch_size)

        state_batch = np.array([batch[0] for batch in experiecne_batch])
        reward_batch = [batch[1] for batch in experiecne_batch]
        action_batch = [batch[2] for batch in experiecne_batch]
        next_state_batch = np.array([batch[3] for batch in experiecne_batch])
        terminate_batch = [batch[4] for batch in experiecne_batch]

        return state_batch, reward_batch, action_batch, next_state_batch, terminate_batch

    def fit(
            self, total_time_steps:int=100000, 
            max_time_steps:int=1000, 
            early_stopping:bool=False, 
            batch_size:int=32, 
            learning_starts:int=50000,
            update_main_model_freq:int=20, 
            update_target_model_freq:int=5000,
            reward_threshold:int=15,
            num_avg_episode_score:int=5,
            check_freq_callback:int=1000, 
            log_callback:bool=True
    ):
        # Setup GPU for training
        physical_devices = tf.config.list_physical_devices('GPU')
        if len(physical_devices) > 0:
            tf.config.set_visible_devices(physical_devices[0], 'GPU')
            print('GPU is available')
        else:
            print('GPU is not available')

        if not os.path.exists('./Results/'):
            os.makedirs('./Results/')

        epsiode_count = 0
        time_step_count = 0
        learning_starts_count = 0

        mean_running_reward = 0
        running_reward_per_episode_list = []
        episode_reward_limit = num_avg_episode_score

        optimizer = Adam(learning_rate=self.learning_rate, clipnorm=1.0)
        loss_function = Huber()

        # Mean running reward threshold for finishing training
        runing_reward_threshold = reward_threshold

        # Train model after a defined frequency
        update_model_frequency = update_main_model_freq

        # Update target model after a defined frequency
        update_target_model_frequency = update_target_model_freq

        print('Start training session..')

        while (time_step_count < total_time_steps)  or not early_stopping:
            terminate = False

            reward_episode = 0.0
            loss = 0

            # Initialize current state
            current_state = np.array(self.env.reset()[0]).transpose([1, 2, 0])

            for time_step in range(max_time_steps):
                # Get action
                current_action = self.act(current_state, self.epsilon, time_step_count)

                # Perform action
                next_state, reward, terminate, _, _ = self.env.step(current_action)
                # Clip reward
                reward = self.clip_reward(reward)
                # Reshape next state data
                next_state = np.array(next_state).transpose([1, 2, 0])
                reward_episode += reward

                # Store experience
                self.store_experience(current_state, reward, current_action, next_state, terminate)

                # Increment time step
                if learning_starts_count <= learning_starts:
                    learning_starts_count = learning_starts_count + 1
                else: 
                    time_step_count = time_step_count + 1

                # Experience replay if reach required time steps and experience batch memory
                if time_step_count % update_model_frequency == 0 and len(self.memory) > batch_size:
                    # Get epericence batch
                    state_batch, reward_batch, action_batch, next_state_batch, terminate_batch = self.get_experience_sample(batch_size)

                    # Get max Q value of next state
                    next_q_value = tf.reduce_max(self.target_model.predict(next_state_batch), axis=1)

                    # Get target reward (groundtruth)
                    # target_value = reward_batch if terminate_batch else reward_batch + self.discount_factor*next_q_value

                    # # Train model
                    # with tf.GradientTape() as tape:               
                    #     # Get all available Q values-actions of current state during feed-forward training session
                    #     current_q_value = self.main_model(state_batch)
                    #     # Create mask to filter only Q values of performed actions
                    #     mask = tf.one_hot(action_batch, self.action_space)
                    #     # Filter Q values
                    #     current_q_value = tf.reduce_sum(tf.multiply(current_q_value, mask), axis=1)
                    #     # Calculate loss function
                    #     loss = loss_function(target_value, current_q_value)

                    # # Backpropagation
                    # # Calculate gradient of loss function
                    # gradients = tape.gradient(loss, self.main_model.trainable_variables)
                    # # Apply gradients to update parameters
                    # optimizer.apply_gradients(zip(gradients, self.main_model.trainable_variables))
                    
                    current_q_value = self.main_model.predict(state_batch)
                    for i in range(batch_size):
                        target_value = -1 if terminate_batch[i] else reward_batch[i] + self.discount_factor*next_q_value[i]
                        current_q_value[i][action_batch[i]] = target_value

                    history = self.main_model.fit(state_batch, current_q_value, verbose=0)
                    loss = history.history['loss'][0]

                # Update target model after required time steps
                if time_step_count % update_target_model_frequency == 0 and time_step_count != 0:
                    self.target_model.set_weights(self.main_model.get_weights())
                    r1, r2, r3, r4, r5 = running_reward_per_episode_list[-5], running_reward_per_episode_list[-4], running_reward_per_episode_list[-3], running_reward_per_episode_list[-2], running_reward_per_episode_list[-1]
                    print(f'Mean running reward {mean_running_reward:.2f} - 5 latest total rewards {r1:.0f}-{r2:.0f}-{r3:.0f}-{r4:.0f}-{r5:.0f} - at episode {epsiode_count} of time step {time_step_count}\t- epsilon: {self.epsilon:.3f}\t- loss: {loss:e}')                   

                # Remove oldest eperience if memory is exceeded
                if len(self.memory) > self.max_memory_length:
                    self.memory.popleft()

                if terminate:
                    break

                # Update new epsilone
                self.update_epsilon(time_step_count)

                # Update current state
                current_state = next_state

                # Save callback models
                if log_callback and time_step_count % check_freq_callback == 0 and time_step_count != 0:
                    folder_path = './Results/'
                    model_name = str(time_step_count) + '_model.h5'
                    file_name = folder_path + model_name
                    self.save_model(file_name)
                    print(f'Model of {time_step_count} time steps is saved to ' + file_name)
            
            # Update mean running reward before checking stopping condition
            if learning_starts_count > learning_starts:
                running_reward_per_episode_list.append(reward_episode)
            # Remove oldest reward if memory is exceeded
            if len(running_reward_per_episode_list) > episode_reward_limit:
                del running_reward_per_episode_list[:1]
            if len(running_reward_per_episode_list) > 0:
                mean_running_reward = np.mean(running_reward_per_episode_list)

            if mean_running_reward > runing_reward_threshold and not early_stopping:
                print(f'Finished training with running reward {mean_running_reward} at episode {epsiode_count}.')
                break
            
            epsiode_count += 1

        if early_stopping:
            print(f'Finished training with running reward {mean_running_reward} at episode {epsiode_count}.')
        
        # Save model
        self.save_model('./Results/last_model.h5')
        print('Latest model is saved to ./Results/last_model.h5')

    def save_model(self, file_path):
        self.main_model.save(file_path)

    def load_model(self, file_path):
        self.main_model = load_model(file_path)

    def test_model(self, env:gym.Env, time_steps:int=4000, record:bool=True):
        if not os.path.exists('./Videos/') and record:
            os.mkdir('./Videos/')

        # Initialized Video recorder
        video = VideoRecorder(env, './Videos/demo.mp4')
        
        total_bricks = 108
        hits_list = []
        rewards_list = []

        epsilon_test = 0.01

        current_state = np.array(env.reset()[0]).transpose([1, 2, 0])

        for time_step in range(time_steps):
            # Record frame
            if record:
                video.capture_frame()

            # Get action
            current_action = self.act(current_state, epsilon_test, 1000000)

            # Perform action
            next_state, reward, terminate, _, info = env.step(current_action)

            # Clip reward
            reward = int(self.clip_reward(reward))
            rewards_list.append(reward) 
            hits_list.append(reward) 

            # Reshape next state data
            current_state = np.array(next_state).transpose([1, 2, 0])

            if terminate:
                bricks_left = total_bricks - np.sum(hits_list)
                print(f'Bricks left to be destroyed: {bricks_left}.')
                hits_list = []

                print(f'Lost 1 life at time step {time_step + 1}.')
                print(info)
                plt.plot(rewards_list, color="blue")
                plt.ylabel("Reward",color="blue",fontsize=14)
                plt.show()
                rewards_list = []

                if info['lives'] == 0:
                    break

        if record:
            video.close()

        env.close()

# %% [markdown]
# ### Initialize preprocessed Atari environment

# %%
def Initialize_environment(game_name):
    env = gym.make(game_name, render_mode='rgb_array')

    # Convert frames to Grayscale then rescale to (84,84)
    env = AtariPreprocessing(env=env, frame_skip=4, terminal_on_life_loss=True, scale_obs=True)
    # Wrapping 4 frames into 1 line for model to learn the context of the environment at the same time
    env = FrameStack(env=env, num_stack=4)
     
    return env

# %% [markdown]
# ### Train DQN model

# %%
# Initialize new environment
env = Initialize_environment('BreakoutNoFrameskip-v4')
# Initialize DQN model
model_3 = DQN(env=env, epsilon_decay=1e-6, learning_rate=0.00025, discount_factor=0.99, initial_epsilon=1.0)
# Train model
model_3.fit(total_time_steps=1000000, max_time_steps=10000, learning_starts=5000, batch_size=32, update_main_model_freq=20, update_target_model_freq=10000, num_avg_episode_score=100, check_freq_callback=10000, early_stopping=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 84, 84, 4)]       0
#
#  conv2d (Conv2D)             (None, 20, 20, 32)        8224
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 64)          32832
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          36928
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 512)               1606144
#
#  dense_1 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 1,686,180
# Trainable params: 1,686,180
# Non-trainable params: 0
# _________________________________________________________________
# GPU is available
# Start training session..
# Mean running reward 0.24 - 5 latest total rewards 0-0-0-0-0 - at episode 393 of time step 10000	- epsilon: 0.990	- loss: 8.525334e-05
# Model of 10000 time steps is saved to ./Results/10000_model.h5
# Mean running reward 0.27 - 5 latest total rewards 0-0-0-0-0 - at episode 650 of time step 20000	- epsilon: 0.980	- loss: 3.169393e-04
# Model of 20000 time steps is saved to ./Results/20000_model.h5
# Mean running reward 0.24 - 5 latest total rewards 0-2-0-0-1 - at episode 914 of time step 30000	- epsilon: 0.971	- loss: 3.650975e-04
# Model of 30000 time steps is saved to ./Results/30000_model.h5
# Mean running reward 0.27 - 5 latest total rewards 0-0-1-0-0 - at episode 1172 of time step 40000	- epsilon: 0.961	- loss: 8.842640e-04
# Model of 40000 time steps is saved to ./Results/40000_model.h5
# Mean running reward 0.37 - 5 latest total rewards 0-0-2-0-0 - at episode 1412 of time step 50000	- epsilon: 0.952	- loss: 4.423563e-04
# Model of 50000 time steps is saved to ./Results/50000_model.h5
# Mean running reward 0.36 - 5 latest total rewards 0-2-0-0-0 - at episode 1671 of time step 60000	- epsilon: 0.942	- loss: 4.422880e-04
# Model of 60000 time steps is saved to ./Results/60000_model.h5
# Mean running reward 0.29 - 5 latest total rewards 0-0-0-0-0 - at episode 1936 of time step 70000	- epsilon: 0.933	- loss: 7.648140e-04
# Model of 70000 time steps is saved to ./Results/70000_model.h5
# Mean running reward 0.24 - 5 latest total rewards 1-0-0-0-0 - at episode 2201 of time step 80000	- epsilon: 0.924	- loss: 1.300389e-03
# Model of 80000 time steps is saved to ./Results/80000_model.h5
# Mean running reward 0.36 - 5 latest total rewards 0-0-1-1-0 - at episode 2455 of time step 90000	- epsilon: 0.915	- loss: 5.471196e-04
# Model of 90000 time steps is saved to ./Results/90000_model.h5
# Mean running reward 0.27 - 5 latest total rewards 0-0-0-0-1 - at episode 2720 of time step 100000	- epsilon: 0.906	- loss: 3.253703e-03
# Model of 100000 time steps is saved to ./Results/100000_model.h5
# Mean running reward 0.21 - 5 latest total rewards 0-0-0-1-0 - at episode 3003 of time step 110000	- epsilon: 0.897	- loss: 1.821622e-03
# Model of 110000 time steps is saved to ./Results/110000_model.h5
# Mean running reward 0.20 - 5 latest total rewards 0-0-0-0-0 - at episode 3270 of time step 120000	- epsilon: 0.888	- loss: 2.780997e-04
# Model of 120000 time steps is saved to ./Results/120000_model.h5
# Mean running reward 0.33 - 5 latest total rewards 0-0-0-0-0 - at episode 3514 of time step 130000	- epsilon: 0.879	- loss: 2.001609e-03
# Model of 130000 time steps is saved to ./Results/130000_model.h5
# Mean running reward 0.35 - 5 latest total rewards 0-0-0-0-0 - at episode 3749 of time step 140000	- epsilon: 0.871	- loss: 5.185119e-04
# Model of 140000 time steps is saved to ./Results/140000_model.h5
# Mean running reward 0.37 - 5 latest total rewards 0-0-0-0-0 - at episode 3997 of time step 150000	- epsilon: 0.862	- loss: 3.276203e-04
# Model of 150000 time steps is saved to ./Results/150000_model.h5
# Mean running reward 0.28 - 5 latest total rewards 0-1-0-0-0 - at episode 4237 of time step 160000	- epsilon: 0.854	- loss: 8.724596e-04
# Model of 160000 time steps is saved to ./Results/160000_model.h5
# Mean running reward 0.40 - 5 latest total rewards 0-0-0-0-1 - at episode 4472 of time step 170000	- epsilon: 0.845	- loss: 4.137718e-03
# Model of 170000 time steps is saved to ./Results/170000_model.h5
# Mean running reward 0.29 - 5 latest total rewards 0-1-0-0-1 - at episode 4721 of time step 180000	- epsilon: 0.837	- loss: 1.368917e-03
# Model of 180000 time steps is saved to ./Results/180000_model.h5
# Mean running reward 0.50 - 5 latest total rewards 2-1-1-0-2 - at episode 4948 of time step 190000	- epsilon: 0.829	- loss: 5.446319e-03
# Model of 190000 time steps is saved to ./Results/190000_model.h5
# Mean running reward 0.36 - 5 latest total rewards 0-0-0-1-1 - at episode 5187 of time step 200000	- epsilon: 0.821	- loss: 1.592966e-03
# Model of 200000 time steps is saved to ./Results/200000_model.h5
# Mean running reward 0.41 - 5 latest total rewards 0-0-0-0-0 - at episode 5415 of time step 210000	- epsilon: 0.812	- loss: 1.239914e-03
# Model of 210000 time steps is saved to ./Results/210000_model.h5
# Mean running reward 0.40 - 5 latest total rewards 0-0-1-2-1 - at episode 5635 of time step 220000	- epsilon: 0.804	- loss: 1.853946e-03
# Model of 220000 time steps is saved to ./Results/220000_model.h5
# Mean running reward 0.56 - 5 latest total rewards 0-1-0-1-1 - at episode 5840 of time step 230000	- epsilon: 0.797	- loss: 1.014644e-03
# Model of 230000 time steps is saved to ./Results/230000_model.h5
# Mean running reward 0.65 - 5 latest total rewards 0-0-1-0-1 - at episode 6043 of time step 240000	- epsilon: 0.789	- loss: 2.110510e-03
# Model of 240000 time steps is saved to ./Results/240000_model.h5
# Mean running reward 0.56 - 5 latest total rewards 0-0-0-1-0 - at episode 6242 of time step 250000	- epsilon: 0.781	- loss: 1.942107e-03
# Model of 250000 time steps is saved to ./Results/250000_model.h5
# Mean running reward 0.69 - 5 latest total rewards 1-2-0-0-0 - at episode 6431 of time step 260000	- epsilon: 0.773	- loss: 1.807117e-03
# Model of 260000 time steps is saved to ./Results/260000_model.h5
# Mean running reward 0.68 - 5 latest total rewards 0-0-1-0-0 - at episode 6625 of time step 270000	- epsilon: 0.766	- loss: 3.930582e-03
# Model of 270000 time steps is saved to ./Results/270000_model.h5
# Mean running reward 0.64 - 5 latest total rewards 1-1-0-0-0 - at episode 6823 of time step 280000	- epsilon: 0.758	- loss: 2.223799e-03
# Model of 280000 time steps is saved to ./Results/280000_model.h5
# Mean running reward 0.66 - 5 latest total rewards 2-0-0-2-0 - at episode 7003 of time step 290000	- epsilon: 0.751	- loss: 5.438384e-03
# Model of 290000 time steps is saved to ./Results/290000_model.h5
# Mean running reward 0.72 - 5 latest total rewards 2-1-1-2-0 - at episode 7179 of time step 300000	- epsilon: 0.743	- loss: 3.141418e-03
# Model of 300000 time steps is saved to ./Results/300000_model.h5
# Mean running reward 0.61 - 5 latest total rewards 4-0-1-0-2 - at episode 7368 of time step 310000	- epsilon: 0.736	- loss: 5.796007e-03
# Model of 310000 time steps is saved to ./Results/310000_model.h5
# Mean running reward 0.78 - 5 latest total rewards 0-1-1-0-2 - at episode 7547 of time step 320000	- epsilon: 0.729	- loss: 2.078310e-03
# Model of 320000 time steps is saved to ./Results/320000_model.h5
# Mean running reward 0.89 - 5 latest total rewards 1-1-1-0-1 - at episode 7704 of time step 330000	- epsilon: 0.722	- loss: 2.766898e-03
# Model of 330000 time steps is saved to ./Results/330000_model.h5
# Mean running reward 0.92 - 5 latest total rewards 2-1-2-0-2 - at episode 7873 of time step 340000	- epsilon: 0.715	- loss: 2.933570e-03
# Model of 340000 time steps is saved to ./Results/340000_model.h5
# Mean running reward 0.75 - 5 latest total rewards 0-0-2-0-0 - at episode 8054 of time step 350000	- epsilon: 0.708	- loss: 2.461722e-03
# Model of 350000 time steps is saved to ./Results/350000_model.h5
# Mean running reward 0.96 - 5 latest total rewards 0-0-2-1-2 - at episode 8214 of time step 360000	- epsilon: 0.701	- loss: 5.362633e-03
# Model of 360000 time steps is saved to ./Results/360000_model.h5
# Mean running reward 0.91 - 5 latest total rewards 0-0-1-2-1 - at episode 8376 of time step 370000	- epsilon: 0.694	- loss: 3.163155e-03
# Model of 370000 time steps is saved to ./Results/370000_model.h5
# Mean running reward 0.97 - 5 latest total rewards 1-0-4-1-0 - at episode 8532 of time step 380000	- epsilon: 0.687	- loss: 1.313551e-02
# Model of 380000 time steps is saved to ./Results/380000_model.h5
# Mean running reward 0.92 - 5 latest total rewards 0-0-3-1-0 - at episode 8690 of time step 390000	- epsilon: 0.680	- loss: 3.545934e-03
# Model of 390000 time steps is saved to ./Results/390000_model.h5
# Mean running reward 0.87 - 5 latest total rewards 0-0-0-0-0 - at episode 8860 of time step 400000	- epsilon: 0.674	- loss: 2.404327e-03
# Model of 400000 time steps is saved to ./Results/400000_model.h5
# Mean running reward 0.96 - 5 latest total rewards 2-1-2-1-1 - at episode 9026 of time step 410000	- epsilon: 0.667	- loss: 4.893459e-03
# Model of 410000 time steps is saved to ./Results/410000_model.h5
# Mean running reward 1.03 - 5 latest total rewards 0-0-1-3-1 - at episode 9184 of time step 420000	- epsilon: 0.660	- loss: 1.287495e-03
# Model of 420000 time steps is saved to ./Results/420000_model.h5
# Mean running reward 1.08 - 5 latest total rewards 0-2-0-3-2 - at episode 9330 of time step 430000	- epsilon: 0.654	- loss: 1.882672e-03
# Model of 430000 time steps is saved to ./Results/430000_model.h5
# Mean running reward 0.91 - 5 latest total rewards 2-0-2-2-0 - at episode 9486 of time step 440000	- epsilon: 0.648	- loss: 2.606522e-03
# Model of 440000 time steps is saved to ./Results/440000_model.h5
# Mean running reward 1.14 - 5 latest total rewards 0-2-0-0-0 - at episode 9640 of time step 450000	- epsilon: 0.641	- loss: 5.218937e-03
# Model of 450000 time steps is saved to ./Results/450000_model.h5
# Mean running reward 0.98 - 5 latest total rewards 1-2-1-2-0 - at episode 9792 of time step 460000	- epsilon: 0.635	- loss: 1.725219e-03
# Model of 460000 time steps is saved to ./Results/460000_model.h5
# Mean running reward 1.20 - 5 latest total rewards 2-1-1-1-5 - at episode 9930 of time step 470000	- epsilon: 0.629	- loss: 1.567676e-03
# Model of 470000 time steps is saved to ./Results/470000_model.h5
# Mean running reward 0.92 - 5 latest total rewards 3-0-1-0-0 - at episode 10078 of time step 480000	- epsilon: 0.623	- loss: 2.813715e-02
# Model of 480000 time steps is saved to ./Results/480000_model.h5
# Mean running reward 1.39 - 5 latest total rewards 0-2-0-2-1 - at episode 10203 of time step 490000	- epsilon: 0.617	- loss: 1.464428e-03
# Model of 490000 time steps is saved to ./Results/490000_model.h5
# Mean running reward 1.28 - 5 latest total rewards 0-2-2-0-2 - at episode 10331 of time step 500000	- epsilon: 0.610	- loss: 2.901305e-03
# Model of 500000 time steps is saved to ./Results/500000_model.h5
# Mean running reward 1.29 - 5 latest total rewards 0-2-0-2-2 - at episode 10461 of time step 510000	- epsilon: 0.604	- loss: 1.509580e-03
# Model of 510000 time steps is saved to ./Results/510000_model.h5
# Mean running reward 1.28 - 5 latest total rewards 2-0-3-0-0 - at episode 10596 of time step 520000	- epsilon: 0.599	- loss: 2.429515e-03
# Model of 520000 time steps is saved to ./Results/520000_model.h5
# Mean running reward 1.12 - 5 latest total rewards 0-0-2-0-4 - at episode 10733 of time step 530000	- epsilon: 0.593	- loss: 4.868567e-04
# Model of 530000 time steps is saved to ./Results/530000_model.h5
# Mean running reward 1.07 - 5 latest total rewards 0-5-1-0-0 - at episode 10871 of time step 540000	- epsilon: 0.587	- loss: 2.789006e-03
# Model of 540000 time steps is saved to ./Results/540000_model.h5
# Mean running reward 1.03 - 5 latest total rewards 0-0-0-0-3 - at episode 11008 of time step 550000	- epsilon: 0.581	- loss: 1.667201e-03
# Model of 550000 time steps is saved to ./Results/550000_model.h5
# Mean running reward 0.72 - 5 latest total rewards 0-0-0-0-1 - at episode 11177 of time step 560000	- epsilon: 0.575	- loss: 6.482414e-03
# Model of 560000 time steps is saved to ./Results/560000_model.h5
# Mean running reward 0.49 - 5 latest total rewards 1-0-0-0-0 - at episode 11370 of time step 570000	- epsilon: 0.570	- loss: 9.775625e-03
# Model of 570000 time steps is saved to ./Results/570000_model.h5
# Mean running reward 0.58 - 5 latest total rewards 0-0-1-0-0 - at episode 11554 of time step 580000	- epsilon: 0.564	- loss: 2.368716e-03
# Model of 580000 time steps is saved to ./Results/580000_model.h5
# Mean running reward 1.09 - 5 latest total rewards 4-0-2-1-2 - at episode 11706 of time step 590000	- epsilon: 0.559	- loss: 1.118688e-03
# Model of 590000 time steps is saved to ./Results/590000_model.h5
# Mean running reward 0.94 - 5 latest total rewards 1-0-0-0-3 - at episode 11858 of time step 600000	- epsilon: 0.553	- loss: 8.955435e-03
# Model of 600000 time steps is saved to ./Results/600000_model.h5
# Mean running reward 1.22 - 5 latest total rewards 0-4-3-2-4 - at episode 11992 of time step 610000	- epsilon: 0.548	- loss: 1.773662e-03
# Model of 610000 time steps is saved to ./Results/610000_model.h5
# Mean running reward 0.85 - 5 latest total rewards 0-2-0-0-3 - at episode 12155 of time step 620000	- epsilon: 0.543	- loss: 3.343783e-03
# Model of 620000 time steps is saved to ./Results/620000_model.h5
# Mean running reward 0.73 - 5 latest total rewards 3-0-0-0-1 - at episode 12325 of time step 630000	- epsilon: 0.537	- loss: 5.285638e-03
# Model of 630000 time steps is saved to ./Results/630000_model.h5
# Mean running reward 0.75 - 5 latest total rewards 0-0-2-3-0 - at episode 12494 of time step 640000	- epsilon: 0.532	- loss: 1.731278e-03
# Model of 640000 time steps is saved to ./Results/640000_model.h5
# Mean running reward 0.80 - 5 latest total rewards 0-0-0-1-0 - at episode 12657 of time step 650000	- epsilon: 0.527	- loss: 2.492670e-03
# Model of 650000 time steps is saved to ./Results/650000_model.h5
# Mean running reward 1.14 - 5 latest total rewards 0-4-0-0-3 - at episode 12801 of time step 660000	- epsilon: 0.522	- loss: 1.290724e-03
# Model of 660000 time steps is saved to ./Results/660000_model.h5
# Mean running reward 1.04 - 5 latest total rewards 1-1-0-0-2 - at episode 12948 of time step 670000	- epsilon: 0.517	- loss: 1.638301e-03
# Model of 670000 time steps is saved to ./Results/670000_model.h5
# Mean running reward 1.27 - 5 latest total rewards 2-2-2-4-0 - at episode 13083 of time step 680000	- epsilon: 0.512	- loss: 3.875743e-03
# Model of 680000 time steps is saved to ./Results/680000_model.h5
# Mean running reward 1.24 - 5 latest total rewards 3-4-0-0-0 - at episode 13214 of time step 690000	- epsilon: 0.507	- loss: 3.548076e-03
# Model of 690000 time steps is saved to ./Results/690000_model.h5
# Mean running reward 1.61 - 5 latest total rewards 4-0-0-0-0 - at episode 13331 of time step 700000	- epsilon: 0.502	- loss: 1.435509e-03
# Model of 700000 time steps is saved to ./Results/700000_model.h5
# Mean running reward 1.58 - 5 latest total rewards 2-0-0-6-4 - at episode 13448 of time step 710000	- epsilon: 0.497	- loss: 8.780920e-03
# Model of 710000 time steps is saved to ./Results/710000_model.h5
# Mean running reward 1.54 - 5 latest total rewards 0-3-3-0-2 - at episode 13568 of time step 720000	- epsilon: 0.492	- loss: 2.037299e-03
# Model of 720000 time steps is saved to ./Results/720000_model.h5
# Mean running reward 1.65 - 5 latest total rewards 0-0-2-1-2 - at episode 13681 of time step 730000	- epsilon: 0.487	- loss: 1.810525e-03
# Model of 730000 time steps is saved to ./Results/730000_model.h5
# Mean running reward 1.72 - 5 latest total rewards 5-2-4-4-0 - at episode 13792 of time step 740000	- epsilon: 0.482	- loss: 1.230935e-02
# Model of 740000 time steps is saved to ./Results/740000_model.h5
# Mean running reward 1.93 - 5 latest total rewards 1-1-0-2-0 - at episode 13892 of time step 750000	- epsilon: 0.478	- loss: 3.165561e-03
# Model of 750000 time steps is saved to ./Results/750000_model.h5
# Mean running reward 1.62 - 5 latest total rewards 0-0-0-3-0 - at episode 14004 of time step 760000	- epsilon: 0.473	- loss: 1.806879e-02
# Model of 760000 time steps is saved to ./Results/760000_model.h5
# Mean running reward 1.56 - 5 latest total rewards 2-0-0-2-0 - at episode 14116 of time step 770000	- epsilon: 0.468	- loss: 2.319658e-03
# Model of 770000 time steps is saved to ./Results/770000_model.h5
# Mean running reward 1.86 - 5 latest total rewards 4-0-4-1-1 - at episode 14219 of time step 780000	- epsilon: 0.464	- loss: 1.110152e-03
# Model of 780000 time steps is saved to ./Results/780000_model.h5
# Mean running reward 1.98 - 5 latest total rewards 3-2-3-2-0 - at episode 14319 of time step 790000	- epsilon: 0.459	- loss: 2.976907e-03
# Model of 790000 time steps is saved to ./Results/790000_model.h5
# Mean running reward 2.12 - 5 latest total rewards 3-5-1-3-2 - at episode 14415 of time step 800000	- epsilon: 0.455	- loss: 1.160887e-03
# Model of 800000 time steps is saved to ./Results/800000_model.h5
# Mean running reward 1.86 - 5 latest total rewards 1-5-3-0-3 - at episode 14523 of time step 810000	- epsilon: 0.450	- loss: 1.663351e-03
# Model of 810000 time steps is saved to ./Results/810000_model.h5
# Mean running reward 2.02 - 5 latest total rewards 2-2-2-4-1 - at episode 14628 of time step 820000	- epsilon: 0.446	- loss: 3.169841e-03
# Model of 820000 time steps is saved to ./Results/820000_model.h5
# Mean running reward 2.19 - 5 latest total rewards 4-0-1-2-5 - at episode 14723 of time step 830000	- epsilon: 0.442	- loss: 5.736282e-03
# Model of 830000 time steps is saved to ./Results/830000_model.h5
# Mean running reward 1.84 - 5 latest total rewards 3-4-1-1-2 - at episode 14828 of time step 840000	- epsilon: 0.437	- loss: 3.482634e-03
# Model of 840000 time steps is saved to ./Results/840000_model.h5
# Mean running reward 2.00 - 5 latest total rewards 0-0-0-3-1 - at episode 14929 of time step 850000	- epsilon: 0.433	- loss: 7.583984e-04
# Model of 850000 time steps is saved to ./Results/850000_model.h5
# Mean running reward 2.03 - 5 latest total rewards 3-0-3-5-1 - at episode 15029 of time step 860000	- epsilon: 0.429	- loss: 1.683783e-03
# Model of 860000 time steps is saved to ./Results/860000_model.h5
# Mean running reward 1.98 - 5 latest total rewards 0-2-2-0-1 - at episode 15129 of time step 870000	- epsilon: 0.425	- loss: 3.114741e-03
# Model of 870000 time steps is saved to ./Results/870000_model.h5
# Mean running reward 1.92 - 5 latest total rewards 0-2-5-2-2 - at episode 15233 of time step 880000	- epsilon: 0.421	- loss: 1.018690e-02
# Model of 880000 time steps is saved to ./Results/880000_model.h5
# Mean running reward 1.96 - 5 latest total rewards 0-0-4-4-0 - at episode 15334 of time step 890000	- epsilon: 0.417	- loss: 2.291693e-03
# Model of 890000 time steps is saved to ./Results/890000_model.h5
# Mean running reward 2.15 - 5 latest total rewards 0-5-1-6-1 - at episode 15427 of time step 900000	- epsilon: 0.413	- loss: 5.708398e-03
# Model of 900000 time steps is saved to ./Results/900000_model.h5
# Mean running reward 1.93 - 5 latest total rewards 2-2-2-3-2 - at episode 15529 of time step 910000	- epsilon: 0.408	- loss: 2.253677e-03
# Model of 910000 time steps is saved to ./Results/910000_model.h5
# Mean running reward 2.30 - 5 latest total rewards 4-4-8-5-0 - at episode 15620 of time step 920000	- epsilon: 0.405	- loss: 1.905790e-03
# Model of 920000 time steps is saved to ./Results/920000_model.h5
# Mean running reward 2.07 - 5 latest total rewards 5-3-1-4-3 - at episode 15718 of time step 930000	- epsilon: 0.401	- loss: 8.706078e-03
# Model of 930000 time steps is saved to ./Results/930000_model.h5
# Mean running reward 2.55 - 5 latest total rewards 1-2-6-4-2 - at episode 15806 of time step 940000	- epsilon: 0.397	- loss: 7.043127e-03
# Model of 940000 time steps is saved to ./Results/940000_model.h5
# Mean running reward 2.13 - 5 latest total rewards 6-3-2-3-5 - at episode 15904 of time step 950000	- epsilon: 0.393	- loss: 2.866657e-03
# Model of 950000 time steps is saved to ./Results/950000_model.h5
# Mean running reward 1.95 - 5 latest total rewards 1-0-0-7-5 - at episode 16007 of time step 960000	- epsilon: 0.389	- loss: 2.871199e-03
# Model of 960000 time steps is saved to ./Results/960000_model.h5
# Mean running reward 2.27 - 5 latest total rewards 2-1-0-0-4 - at episode 16096 of time step 970000	- epsilon: 0.385	- loss: 2.005997e-02
# Model of 970000 time steps is saved to ./Results/970000_model.h5
# Mean running reward 2.15 - 5 latest total rewards 0-4-2-1-1 - at episode 16190 of time step 980000	- epsilon: 0.382	- loss: 9.001042e-03
# Model of 980000 time steps is saved to ./Results/980000_model.h5
# Mean running reward 1.70 - 5 latest total rewards 4-4-5-3-0 - at episode 16299 of time step 990000	- epsilon: 0.378	- loss: 1.684269e-03
# Model of 990000 time steps is saved to ./Results/990000_model.h5
# Mean running reward 1.71 - 5 latest total rewards 2-4-0-3-0 - at episode 16411 of time step 1000000	- epsilon: 0.374	- loss: 2.104129e-03
# Model of 1000000 time steps is saved to ./Results/1000000_model.h5
# Finished training with running reward 1.76 at episode 16412.
# Latest model is saved to ./Results/last_model.h5

# %% [markdown]
# ### Test model

# %%
model_3.test_model(env=env, record=True)
# Out:
# Bricks left to be destroyed: 102.
# Lost 1 life at time step 206.
# {'lives': 4, 'episode_frame_number': 825, 'frame_number': 4245875}
# Bricks left to be destroyed: 104.
# Lost 1 life at time step 494.
# {'lives': 3, 'episode_frame_number': 1974, 'frame_number': 4247024}
# Bricks left to be destroyed: 104.
# Lost 1 life at time step 874.
# {'lives': 2, 'episode_frame_number': 3494, 'frame_number': 4248544}
# Bricks left to be destroyed: 107.
# Lost 1 life at time step 926.
# {'lives': 1, 'episode_frame_number': 3700, 'frame_number': 4248750}
# Bricks left to be destroyed: 99.
# Lost 1 life at time step 1243.
# {'lives': 0, 'episode_frame_number': 4967, 'frame_number': 4250017}
# Moviepy - Building video ./Videos/demo.mp4.
# Moviepy - Writing video ./Videos/demo.mp4
# Moviepy - Done !
# Moviepy - video ready ./Videos/demo.mp4

# %%
# Initialize new environment
env = Initialize_environment('BreakoutNoFrameskip-v4')
# Initialize model
inference_model = DQN(env=env)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 84, 84, 4)]       0
#
#  conv2d_6 (Conv2D)           (None, 20, 20, 32)        8224
#
#  conv2d_7 (Conv2D)           (None, 9, 9, 64)          32832
#
#  conv2d_8 (Conv2D)           (None, 7, 7, 64)          36928
#
#  flatten_2 (Flatten)         (None, 3136)              0
#
#  dense_4 (Dense)             (None, 512)               1606144
#
#  dense_5 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 1,686,180
# Trainable params: 1,686,180
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Load model
inference_model.load_model('./Results/920000_model.h5')
# Test model
inference_model.test_model(env=env, record=True)
# Out:
# Bricks left to be destroyed: 101.
# Lost 1 life at time step 240.
# {'lives': 4, 'episode_frame_number': 963, 'frame_number': 4617}
# Bricks left to be destroyed: 105.
# Lost 1 life at time step 378.
# {'lives': 3, 'episode_frame_number': 1514, 'frame_number': 5168}
# Bricks left to be destroyed: 104.
# Lost 1 life at time step 621.
# {'lives': 2, 'episode_frame_number': 2484, 'frame_number': 6138}
# Bricks left to be destroyed: 106.
# Lost 1 life at time step 711.
# {'lives': 1, 'episode_frame_number': 2843, 'frame_number': 6497}
# Bricks left to be destroyed: 104.
# Lost 1 life at time step 893.
# {'lives': 0, 'episode_frame_number': 3569, 'frame_number': 7223}
# Moviepy - Building video ./Videos/demo.mp4.
# Moviepy - Writing video ./Videos/demo.mp4
# Moviepy - Done !
# Moviepy - video ready ./Videos/demo.mp4
